# %%
import matplotlib.pyplot as plt
import json
data_file = open('../cedict.json', 'r', encoding='utf-8')
data = json.load(data_file)

scores_in = []
scores_ex = []
for d in data:
    scores_in.append(d["word_score_in"])
    scores_ex.append(d["word_score_ex"])

# %%
# Set range limits to focus on non-outlier data
plt.figure(figsize=(12, 5))
plt.hist(scores_in, bins=30, range=(0, 100000), alpha=0.7, label='Word Score In', color='blue', edgecolor='black')

# Add labels and legend
plt.title('Distribution of Word Scores (Outliers Removed)', fontsize=16)
plt.xlabel('Score', fontsize=14)
plt.ylabel('Frequency', fontsize=14)
plt.legend(fontsize=12)
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Show the plot
plt.tight_layout()
plt.show()

# %%
# Set range limits to focus on non-outlier data
plt.figure(figsize=(12, 5))
plt.hist(scores_ex, bins=30, range=(0, 100000), alpha=0.7, label='Word Score Ex', color='blue', edgecolor='black')

# Add labels and legend
plt.title('Distribution of Word Scores (Outliers Removed)', fontsize=16)
plt.xlabel('Score', fontsize=14)
plt.ylabel('Frequency', fontsize=14)
plt.legend(fontsize=12)
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Show the plot
plt.tight_layout()
plt.show()

# %%
import numpy as np
percentiles_in = [np.percentile(scores_in, p) for p in range(0, 101, 10)]
percentiles_ex = [np.percentile(scores_ex, p) for p in range(0, 101, 10)]

print("Scores in percentiles")
for i, p in enumerate(range(0, 101, 10)):
    print(f"{p}th Percentile: {percentiles_in[i]}")

print("Scores ex percentiles")
for i, p in enumerate(range(0, 101, 10)):
    print(f"{p}th Percentile: {percentiles_ex[i]}")
# Out:
# Scores in percentiles
# 0th Percentile: 0.0
# 10th Percentile: 528.5
# 20th Percentile: 1348.0
# 30th Percentile: 2167.0
# 40th Percentile: 3037.0
# 50th Percentile: 4047.0
# 60th Percentile: 5255.0
# 70th Percentile: 6859.0
# 80th Percentile: 9160.0
# 90th Percentile: 13453.5
# 100th Percentile: 230500.0
# Scores ex percentiles
# 0th Percentile: 0.0
# 10th Percentile: 3061.0
# 20th Percentile: 6421.0
# 30th Percentile: 9243.0
# 40th Percentile: 11940.0
# 50th Percentile: 14721.0
# 60th Percentile: 18027.0
# 70th Percentile: 22131.5
# 80th Percentile: 27819.0
# 90th Percentile: 37911.0
# 100th Percentile: 562800.0
